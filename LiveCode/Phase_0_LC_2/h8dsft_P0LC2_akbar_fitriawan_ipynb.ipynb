# %% [markdown]
# ---
# ### =================================================
# Live Code 2
#
# Nama  : Akbar Fitriawan
# Batch : HCK-14
#
# ### =================================================
# ---

# %%
# conecting data
from google.colab import auth
from google.cloud import bigquery
auth.authenticate_user()
print('Authenticated')

project_id_akun = "lively-metrics-415004" #GUNAKAN GCP PROJECT-ID KALIAN MASING-MASING
client = bigquery.Client(project=project_id_akun)
# Out:
# Authenticated

# %%
import pandas as pd

# %%
# load data
df = client.query('''
SELECT *
FROM ftds-hacktiv8-project.phase0_ftds_014_hck.beverage_sales
''').to_dataframe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6014 entries, 0 to 6013
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   invoice_id             6014 non-null   object
#  1   date                   6014 non-null   dbdate
#  2   store_id               6014 non-null   Int64
#  3   store_name             6014 non-null   object
#  4   store_city             6014 non-null   object
#  5   product_name           6014 non-null   object
#  6   manufacturing_company  6014 non-null   object
#  7   pack                   6014 non-null   Int64
#  8   unit_volume_ml         6014 non-null   Int64
#  9   unit_sold              6014 non-null   Int64
#  10  unit_retail_price      6014 non-null   float64
#  11  total_price            6014 non-null   float64
#  12  volume_sold_liters     6014 non-null   float64
# dtypes: Int64(4), dbdate(1), float64(3), object(5)
# memory usage: 634.4+ KB

# %% [markdown]
# # Problem 1 - SQL

# %%
df.head()
# Out:
#         invoice_id        date  store_id  store_name store_city  \
# 0  INV-58839200013  2023-05-26      6016  Metro Mall   CLARINDA
# 1  INV-56953900014  2023-03-24      6016  Metro Mall   CLARINDA
# 2  INV-56345300016  2023-03-03      6016  Metro Mall   CLARINDA
# 3  INV-32274100025  2020-11-27      6016  Metro Mall   CLARINDA
# 4  INV-32274100030  2020-11-27      6016  Metro Mall   CLARINDA
#
#            product_name manufacturing_company  pack  unit_volume_ml  \
# 0   OasisGlow Refresher    NibbleNation Group    12              50
# 1       PureElixir Zest      MunchWave Snacks    12              50
# 2  Sparkling Bliss Brew    BiteBlend Delights    12             750
# 3      VelvetChai Charm      OliverCraft Inc.    12             750
# 4  FruitFusion Quencher       CrunchCraft Co.    24             375
#
#    unit_sold  unit_retail_price  total_price  volume_sold_liters
# 0          4               1.25         5.00                0.20
# 1          5               1.30         6.50                0.25
# 2          5               1.55         7.75                3.75
# 3          6               1.75        10.50                4.50
# 4         24               1.22        12.00                9.00

# %% [markdown]
# 1. Kota apa saja yang masuk ke dalam cakupan wilayah distribusi?
#
#   Answer

# %%
df = client.query('''
SELECT DISTINCT(store_city)
FROM ftds-hacktiv8-project.phase0_ftds_014_hck.beverage_sales
''').to_dataframe()

df
# Out:
#         store_city
# 0         CLARINDA
# 1        MUSCATINE
# 2       MASON CITY
# 3  WEST DES MOINES
# 4          CLINTON
# 5      CEDAR FALLS

# %% [markdown]
# 2. Berapa rentang harga minimum dan maksimum dari unit minumam yang dijual?

# %%
df = client.query('''
SELECT
  min(unit_retail_price) as harga_min,
  max(unit_retail_price) as harga_max
FROM ftds-hacktiv8-project.phase0_ftds_014_hck.beverage_sales


''').to_dataframe()

df
# Out:
#    harga_min  harga_max
# 0       0.98       54.0

# %% [markdown]
# 3. Bandingkan total penjualan dan jumlah transaksi dari masing-masing kota pada tahun 2022?

# %%
df = client.query('''
SELECT
  store_city,
  EXTRACT (YEAR FROM date) as years,
  COUNT(invoice_id) as total_penjualan
FROM ftds-hacktiv8-project.phase0_ftds_014_hck.beverage_sales
WHERE EXTRACT (YEAR FROM date) = 2022
GROUP BY store_city, years

''').to_dataframe()

df
# Out:
#         store_city  years  total_penjualan
# 0         CLARINDA   2022              248
# 1        MUSCATINE   2022              234
# 2       MASON CITY   2022               47
# 3  WEST DES MOINES   2022               47
# 4          CLINTON   2022              387
# 5      CEDAR FALLS   2022              417

# %% [markdown]
# 4. Produk apa yang paling banyak diminati pada tahun 2022?

# %%
df = client.query('''
SELECT
  DISTINCT(product_name)
  product_name,
  EXTRACT (YEAR FROM date) as years,
  COUNT(*) as count
FROM ftds-hacktiv8-project.phase0_ftds_014_hck.beverage_sales

WHERE EXTRACT (YEAR FROM date) = 2022
group by product_name, years
order by count desc
limit 3

''').to_dataframe()

df
# Out:
#            product_name  years  count
# 0  FruitFusion Quencher   2022    291
# 1  Sparkling Bliss Brew   2022    120
# 2       VitaWave Splash   2022    111

# %% [markdown]
# # Problem 2 - Pandas
#
# Answer

# %% [markdown]
#  ## 1. buat kolom baru, menunjukkan representasi musim dengan ketentuan berikut:
# |`Musim` |	Bulan|
# |--|--|
# `Spring`	| Maret, April, Mei
# `Summer`	| Juni, Juli, Agustus
# `Autumn`	| September, Oktober, November
# `Winter`	| Desember, Januari, Februari

# %%
df = client.query('''
SELECT *
FROM ftds-hacktiv8-project.phase0_ftds_014_hck.beverage_sales
''').to_dataframe()
df.head()
# Out:
#         invoice_id        date  store_id  store_name store_city  \
# 0  INV-58839200013  2023-05-26      6016  Metro Mall   CLARINDA
# 1  INV-56953900014  2023-03-24      6016  Metro Mall   CLARINDA
# 2  INV-56345300016  2023-03-03      6016  Metro Mall   CLARINDA
# 3  INV-32274100025  2020-11-27      6016  Metro Mall   CLARINDA
# 4  INV-32274100030  2020-11-27      6016  Metro Mall   CLARINDA
#
#            product_name manufacturing_company  pack  unit_volume_ml  \
# 0   OasisGlow Refresher    NibbleNation Group    12              50
# 1       PureElixir Zest      MunchWave Snacks    12              50
# 2  Sparkling Bliss Brew    BiteBlend Delights    12             750
# 3      VelvetChai Charm      OliverCraft Inc.    12             750
# 4  FruitFusion Quencher       CrunchCraft Co.    24             375
#
#    unit_sold  unit_retail_price  total_price  volume_sold_liters
# 0          4               1.25         5.00                0.20
# 1          5               1.30         6.50                0.25
# 2          5               1.55         7.75                3.75
# 3          6               1.75        10.50                4.50
# 4         24               1.22        12.00                9.00

# %%
# function untuk mengubah bulan ke season
def month_to_season(month):
  if month in [3,4,5]:
    return 'Spring'
  elif month in [6,7,8]:
    return 'Summer'
  elif month in [9,10,11]:
    return 'Autumn'
  else:
    return 'Winter'

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y/%m/%d')

# extract bulan dari column date
df['month'] = df['date'].dt.month

# %%
# apply fungsi ke dataframe
df['Season'] = df['month'].apply(month_to_season)

# %%
df
# Out:
#            invoice_id       date  store_id       store_name   store_city  \
# 0     INV-58839200013 2023-05-26      6016       Metro Mall     CLARINDA
# 1     INV-56953900014 2023-03-24      6016       Metro Mall     CLARINDA
# 2     INV-56345300016 2023-03-03      6016       Metro Mall     CLARINDA
# 3     INV-32274100025 2020-11-27      6016       Metro Mall     CLARINDA
# 4     INV-32274100030 2020-11-27      6016       Metro Mall     CLARINDA
# ...               ...        ...       ...              ...          ...
# 6009  INV-46502900008 2022-04-14      4119  Peak Provisions  CEDAR FALLS
# 6010  INV-35080700016 2021-03-17      4119  Peak Provisions  CEDAR FALLS
# 6011  INV-20939700005 2019-07-30      4119  Peak Provisions  CEDAR FALLS
# 6012  INV-50461000007 2022-08-18      4119  Peak Provisions  CEDAR FALLS
# 6013  INV-51677600017 2022-09-29      4119  Peak Provisions  CEDAR FALLS
#
#               product_name   manufacturing_company  pack  unit_volume_ml  \
# 0      OasisGlow Refresher      NibbleNation Group    12              50
# 1          PureElixir Zest        MunchWave Snacks    12              50
# 2     Sparkling Bliss Brew      BiteBlend Delights    12             750
# 3         VelvetChai Charm        OliverCraft Inc.    12             750
# 4     FruitFusion Quencher         CrunchCraft Co.    24             375
# ...                    ...                     ...   ...             ...
# 6009     CocoCrave Delight  TasteTwist Enterprises    12             750
# 6010     CocoCrave Delight  TasteTwist Enterprises    12             750
# 6011  FruitFusion Quencher         CrunchCraft Co.     6            1750
# 6012    FrostedCocoa Savor        OliverCraft Inc.    12             750
# 6013    FrostedCocoa Savor        OliverCraft Inc.    12             750
#
#       unit_sold  unit_retail_price  total_price  volume_sold_liters  month  \
# 0             4               1.25         5.00                0.20      5
# 1             5               1.30         6.50                0.25      3
# 2             5               1.55         7.75                3.75      3
# 3             6               1.75        10.50                4.50     11
# 4            24               1.22        12.00                9.00     11
# ...         ...                ...          ...                 ...    ...
# 6009         12               6.07        72.84                9.00      4
# 6010         24               6.07       145.68               18.00      3
# 6011         18               1.94        34.92               31.50      7
# 6012         12               3.91        46.92                9.00      8
# 6013         12               3.91        46.92                9.00      9
#
#       Season
# 0     Spring
# 1     Spring
# 2     Spring
# 3     Autumn
# 4     Autumn
# ...      ...
# 6009  Spring
# 6010  Spring
# 6011  Summer
# 6012  Summer
# 6013  Autumn
#
# [6014 rows x 15 columns]

# %% [markdown]
# Penambahan column Season dengan kriteria dimana:
# Jika transaksi dilakukan di bulan 3, 4, 5 (Maret, April, Mei) akan masuk ke Season Spring.
# Jika transaksi dilakukan di bulan 6, 7, 8 (Juni, Juli, Agustus) akan masuk ke Season Summer.
# Jika transaksi dilakukan di bulan 9, 10, 11 (September, Oktober, November) akan masuk ke Season Autumn.
# Jika transaksi dilakukan di bulan 12, 1, 2 (Desember, Januari, Februari) akan masuk ke Season Winter.

# %% [markdown]
# 2. Berapa total barang yang terjual kepada toko Peak Provisions sepanjang tahun 2022? (Gunakan pandas query untuk menjawab soal no. 2)

# %%
# mengganti format date menjadi datetime
df['date'] = pd.to_datetime(df['date'], format='%Y/%m/%d')

# %%
# extract tahun dari column date
df['year'] = df['date'].dt.year

# %%
df_total_sales = df[(df['store_name'] == 'Peak Provisions') & (df['year'] == 2022)]

# %%
df_total_sales
# Out:
#            invoice_id       date  store_id       store_name   store_city  \
# 3901  INV-44196100009 2022-01-27      4119  Peak Provisions  CEDAR FALLS
# 3908  INV-50461000009 2022-08-18      4119  Peak Provisions  CEDAR FALLS
# 3909  INV-53810400030 2022-12-08      4119  Peak Provisions  CEDAR FALLS
# 3921  INV-44629900011 2022-02-10      4119  Peak Provisions  CEDAR FALLS
# 3922  INV-48841500005 2022-06-30      4119  Peak Provisions  CEDAR FALLS
# ...               ...        ...       ...              ...          ...
# 5971  INV-54050500001 2022-12-15      4119  Peak Provisions  CEDAR FALLS
# 5992  INV-43590700013 2022-01-06      4119  Peak Provisions  CEDAR FALLS
# 6009  INV-46502900008 2022-04-14      4119  Peak Provisions  CEDAR FALLS
# 6012  INV-50461000007 2022-08-18      4119  Peak Provisions  CEDAR FALLS
# 6013  INV-51677600017 2022-09-29      4119  Peak Provisions  CEDAR FALLS
#
#               product_name   manufacturing_company  pack  unit_volume_ml  \
# 3901    CitrusBurst Breeze        MunchWave Snacks     6            1750
# 3908       ChocoMint Bliss      NibbleNation Group     1             100
# 3909       ChocoMint Bliss      NibbleNation Group     1             100
# 3921   VelvetMist Infusion        MunchWave Snacks     6             750
# 3922   VelvetMist Infusion        MunchWave Snacks     6             750
# ...                    ...                     ...   ...             ...
# 5971  Sparkling Bliss Brew      BiteBlend Delights     6            1750
# 5992     CocoCrave Delight      BiteBlend Delights    12             750
# 6009     CocoCrave Delight  TasteTwist Enterprises    12             750
# 6012    FrostedCocoa Savor        OliverCraft Inc.    12             750
# 6013    FrostedCocoa Savor        OliverCraft Inc.    12             750
#
#       unit_sold  unit_retail_price  total_price  volume_sold_liters  month  \
# 3901          6               3.50        21.00                10.5      1
# 3908          1              27.00        27.00                 0.1      8
# 3909          1              27.00        27.00                 0.1     12
# 3921          6               7.25        43.50                 4.5      2
# 3922          6               7.25        43.50                 4.5      6
# ...         ...                ...          ...                 ...    ...
# 5971         12               2.82        33.84                21.0     12
# 5992         12               4.32        51.84                 9.0      1
# 6009         12               6.07        72.84                 9.0      4
# 6012         12               3.91        46.92                 9.0      8
# 6013         12               3.91        46.92                 9.0      9
#
#       Season  year
# 3901  Winter  2022
# 3908  Summer  2022
# 3909  Winter  2022
# 3921  Winter  2022
# 3922  Summer  2022
# ...      ...   ...
# 5971  Winter  2022
# 5992  Winter  2022
# 6009  Spring  2022
# 6012  Summer  2022
# 6013  Autumn  2022
#
# [417 rows x 16 columns]

# %%
total_unit_sold = df_total_sales['unit_sold'].sum()
print('total barang unit yang terjual di toko Peak Provisions di sepanjang tahun 2022  adalah',total_unit_sold)
# Out:
# total barang unit yang terjual di toko Peak Provisions di sepanjang tahun 2022  adalah 4592

# %% [markdown]
# Total barang yang terjual kepada toko 'Peak Provisions' sepanjang tahun 2022 adalah 4592.

# %% [markdown]
# # Kesimpulan Akhir

# %% [markdown]
# Dengan 6 kota distribusi yang berada di Clarinda, Muscatine, Mason City, West Des Moines, Clinton, dan Cedar Falls memiliki harga minuman minimal 0.98 dan maksimum 54. Di tahun 2022, kota Cedar Falls berhasil mendapatkan total penjualan terbanyak dengan 417 total penjualan. Produk minuman yang paling banyak diminati di tahun 2022 adalah FruitFusion Quencher dengan total penjualan 291 unit. Total barang yang terjual kepada toko Peak Provisions sepanjang tahun 2022 adalah 4592 unit.
