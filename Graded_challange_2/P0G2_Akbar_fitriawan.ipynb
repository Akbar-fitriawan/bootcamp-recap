# %% [markdown]
# ---
# ### =================================================
# # Graded Challenge 2
#
# ### Nama  : Akbar Fitriawan
# ### Batch : HCK-14
#
# ### Program ini dibuat untuk melakukan pengolahan data meliputi data exploration, data cleaning, dan data normalisasi
# ### =================================================
# ---

# %% [markdown]
# ---
# # 1. Data Exploration

# %% [markdown]
# ## 1.a Load data

# %%
# load dataset dengan link
import pandas as pd
import numpy as np


df = pd.read_csv('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/Financials.csv')

df
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %% [markdown]
# - Melihat 5 data teratas

# %%
df.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold   \
# 0  Government   Canada   Carretera            None    $1,618.50
# 1  Government  Germany   Carretera            None    $1,321.00
# 2   Midmarket   France   Carretera            None    $2,178.00
# 3   Midmarket  Germany   Carretera            None      $888.00
# 4   Midmarket   Mexico   Carretera            None    $2,470.00
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 0                $3.00       $20.00    $32,370.00        $-      $32,370.00
# 1                $3.00       $20.00    $26,420.00        $-      $26,420.00
# 2                $3.00       $15.00    $32,670.00        $-      $32,670.00
# 3                $3.00       $15.00    $13,320.00        $-      $13,320.00
# 4                $3.00       $15.00    $37,050.00        $-      $37,050.00
#
#           COGS        Profit         Date  Month Number  Month Name   Year
# ...

# %% [markdown]
# - Melihat 5 data terbawah

# %%
# Out:
# 9

# %% [markdown]
# ## 1.b Informasi summary data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                700 non-null    object
#  1   Country                700 non-null    object
#  2    Product               700 non-null    object
#  3    Discount Band         700 non-null    object
#  4    Units Sold            700 non-null    object
#  5    Manufacturing Price   700 non-null    object
#  6    Sale Price            700 non-null    object
#  7    Gross Sales           700 non-null    object
#  8    Discounts             700 non-null    object
#  9     Sales                700 non-null    object
#  10   COGS                  700 non-null    object
#  11   Profit                700 non-null    object
#  12  Date                   700 non-null    object
#  13  Month Number           700 non-null    int64
# ...

# %% [markdown]
# - Jumlah baris dan kolom

# %%
# jumlah baris dan kolom
print("Jumlah Baris :",df.shape[0])
print("Jumlah kolom :",df.shape[1])
# Out:
# Jumlah Baris : 700
# Jumlah kolom : 16

# %% [markdown]
# Dari informasi diatas kita bisa menyimpulkan sebagai berikut:
# - jumlah baris adalah 700 dan memiliki 16 kolom
# - untuk tipe data memiliki integer berjumlah 2 dan object berjumlah 14
# - untuk tipe data diatas termasuk tidak konsisten artinya ada beberapa kolom yang tidak sesuai dengan ketentuan

# %% [markdown]
# ## 1.c Informasi kolom

# %%
# check kolom
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', ' Units Sold ',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
# check tipe data di setiap kolom
df.dtypes.to_frame(name='tipe data')
# Out:
#                       tipe data
# Segment                  object
# Country                  object
#  Product                 object
#  Discount Band           object
#  Units Sold              object
#  Manufacturing Price     object
#  Sale Price              object
#  Gross Sales             object
#  Discounts               object
#   Sales                  object
#  COGS                    object
#  Profit                  object
# Date                     object
# Month Number              int64
#  Month Name              object
# Year                      int64

# %% [markdown]
# Dari informasi di atas ada beberapa tipe data yang tidak sesuai dengan ketentuan seperti   "Units Sold, Manufacturing Price, Gross Sales, Sales, COGS, Date dan lain-lain sesuai di butuhkan", selanjutnya kita merubahnya di cleaning data

# %% [markdown]
# Informasi data tersebut adalah sebagai berikut :
#
# Judul | Definisi
# ---|---
# `Segment` | Segament pasar berdasarkan tingkatan bisnis
# `Country` | Kategori penjualan di beberapa negara
# `Product` | Jenis produk yang di jual
# `Discount Band` | Kategori diskon
# `Units Sold` | Unit terjual
# `Manufacturing Price` | Harga pembuatan atau biaya produksi
# `Sale Price` | Harga jual
# `Gross Sales` | Penjualan kotor
# `Discounts` | Diskon atau potongan harga
# `Sales` | Penjualan
# `COGS` | "Cost of Goods Sold", Ini mengacu pada biaya produksi barang
# `Profit` | Pendapatan
# `Date` | Tanggal laporan data tersebut
# `Month Number` | Data bulan tersebut
# `Month Name` | Nama bulan data tersebut
# `year` | Tahun

# %% [markdown]
# ## 1.d Check nilai unik masing-masing kolom "Segment", "Country", "Product", "Discount Band"

# %%
# nilai unik beberapa kolom
df.nunique()
# Out:
# Segment                    5
# Country                    5
#  Product                   6
#  Discount Band             4
#  Units Sold              510
#  Manufacturing Price       6
#  Sale Price                7
#  Gross Sales             550
#  Discounts               515
#   Sales                  559
#  COGS                    545
#  Profit                  557
# Date                      16
# Month Number              12
#  Month Name               12
# Year                       2
# dtype: int64

# %%
# check jumlah nilai unik segment
nilai_unik_segment = len(pd.unique(df['Segment']))
print('Jumlah nilai unik Segment : ', nilai_unik_segment,'\n')
print(pd.unique(df['Segment'].values))
# Out:
# Jumlah nilai unik Segment :  5
#
# ['Government' 'Midmarket' 'Channel Partners' 'Enterprise' 'Small Business']

# %% [markdown]
# Data kolom segment memiliki 5 unik data yang mana sebagai ketegori berikut: Goverment, Midmarket, Channel Partners, Enterprise dan Small Business

# %%
# check jumlah nilai unik Country
nilai_unik_country = len(pd.unique(df['Country']))
print('Jumlah nilai unik Country : ', nilai_unik_country,'\n')
print(pd.unique(df['Country'].values))
# Out:
# Jumlah nilai unik Country :  5
#
# ['Canada' 'Germany' 'France' 'Mexico' 'United States of America']

# %% [markdown]
# Data kolom country memiliki 5 unik data yang mana sebagai kategori negara 'Canada', 'Germany', 'France', 'Mexico', dan 'United States of America'

# %%
# check jumlah nilai unik Product
nilai_unik_product = len(pd.unique(df[' Product ']))
print('Jumlah nilai unik Product : ', nilai_unik_product,'\n')
print(pd.unique(df[' Product '].values))
# Out:
# Jumlah nilai unik Product :  6
#
# [' Carretera ' ' Montana ' ' Paseo ' ' Velo ' ' VTT ' ' Amarilla ']

# %% [markdown]
# Data kolom product memiliki 6 unik data untuk jenis product ' Carretera ', ' Montana ', ' Paseo ', ' Velo ', ' VTT ', dan ' Amarilla '

# %%
# check jumlah nilai unik Discount band
nilai_unik_discount_band = len(pd.unique(df[' Discount Band ']))
print('Jumlah nilai unik Discount Band : ', nilai_unik_discount_band,'\n')
print(pd.unique(df[' Discount Band '].values))
# Out:
# Jumlah nilai unik Discount Band :  4
#
# [' None ' ' Low ' ' Medium ' ' High ']

# %% [markdown]
# Data kolom Discount band memiliki 4 data unik yaitu ' None ', ' Low ', ' Medium ', dan ' High ' untuk None kita telusuri di cleaning data

# %% [markdown]
# ---
# # 2. Data Cleaning

# %% [markdown]
# ## 2.a Manipulasi kolom

# %%
# Ubah nama kolom
df.columns = df.columns.str.strip().str.lower().str.replace(' ','_')
df.columns
# Out:
# Index(['segment', 'country', 'product', 'discount_band', 'units_sold',
#        'manufacturing_price', 'sale_price', 'gross_sales', 'discounts',
#        'sales', 'cogs', 'profit', 'date', 'month_number', 'month_name',
#        'year'],
#       dtype='object')

# %%
df.head()
# Out:
#       segment  country      product discount_band   units_sold  \
# 0  Government   Canada   Carretera          None    $1,618.50
# 1  Government  Germany   Carretera          None    $1,321.00
# 2   Midmarket   France   Carretera          None    $2,178.00
# 3   Midmarket  Germany   Carretera          None      $888.00
# 4   Midmarket   Mexico   Carretera          None    $2,470.00
#
#   manufacturing_price sale_price   gross_sales discounts         sales  \
# 0              $3.00     $20.00    $32,370.00      $-      $32,370.00
# 1              $3.00     $20.00    $26,420.00      $-      $26,420.00
# 2              $3.00     $15.00    $32,670.00      $-      $32,670.00
# 3              $3.00     $15.00    $13,320.00      $-      $13,320.00
# 4              $3.00     $15.00    $37,050.00      $-      $37,050.00
#
#            cogs        profit        date  month_number month_name  year
# 0   $16,185.00    $16,185.00   01/01/2014             1   January   2014
# ...

# %%
# hapus kolom yang tidak di perlukan
df.drop(columns=['month_number','month_name','year'], inplace=True)

# %%
# marubah nama kolom 'date'  jadi tanggal
df.rename(columns={'date':'tanggal'},inplace=True)

# %% [markdown]
# ## 2.b Hapus data inkonsisten dan merubah tipe data

# %%
# data yang belum diketahuai minus atau bukan
data_minus = df.loc[df['profit'].str.contains('\(.*\)', regex=True)]
data_minus.tail(10)
# Out:
#         segment                   country      product discount_band  \
# 647  Enterprise                    Mexico        Velo          High
# 659  Enterprise  United States of America    Amarilla          High
# 666  Enterprise                    France   Carretera          High
# 667  Enterprise                   Germany   Carretera          High
# 668  Enterprise                   Germany   Carretera          High
# 676  Enterprise                   Germany       Paseo          High
# 684  Enterprise                    France        Velo          High
# 686  Enterprise  United States of America        Velo          High
# 692  Enterprise                    Canada         VTT          High
# 693  Enterprise                   Germany         VTT          High
#
#       units_sold manufacturing_price sale_price     gross_sales     discounts  \
# 647   $1,575.00             $120.00    $125.00    $1,96,875.00    $27,562.50
# ...

# %% [markdown]
# - hapus tanda yang tidak di butuhkan

# %%
# hapus tanda yang tidak dibutuhkan
df[df.columns[4:12]] = df[df.columns[4:12]].replace(to_replace=r'[ ()$,]',value='',regex=True)

# hapus tanda - jadi 0
df["discounts"] = df["discounts"].str.replace(pat='-', repl='0', regex=True)
df['profit'] = df['profit'].str.replace(pat='-', repl='0',regex=True)

# %%
df.head()
# Out:
#       segment  country      product discount_band units_sold  \
# 0  Government   Canada   Carretera          None     1618.50
# 1  Government  Germany   Carretera          None     1321.00
# 2   Midmarket   France   Carretera          None     2178.00
# 3   Midmarket  Germany   Carretera          None      888.00
# 4   Midmarket   Mexico   Carretera          None     2470.00
#
#   manufacturing_price sale_price gross_sales discounts     sales      cogs  \
# 0                3.00      20.00    32370.00         0  32370.00  16185.00
# 1                3.00      20.00    26420.00         0  26420.00  13210.00
# 2                3.00      15.00    32670.00         0  32670.00  21780.00
# 3                3.00      15.00    13320.00         0  13320.00   8880.00
# 4                3.00      15.00    37050.00         0  37050.00  24700.00
#
#      profit     tanggal
# 0  16185.00  01/01/2014
# 1  13210.00  01/01/2014
# 2  10890.00  01/06/2014
# 3   4440.00  01/06/2014
# ...

# %% [markdown]
# - konversi tipe data

# %%
# konversi data yang bersifat currency jadi float
df[df.columns[5:12]] = df[df.columns[5:12]].astype(float)

# %%
# konversi tanggal
df['tanggal'] = pd.to_datetime(df['tanggal'], format='%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   segment              700 non-null    object
#  1   country              700 non-null    object
#  2   product              700 non-null    object
#  3   discount_band        700 non-null    object
#  4   units_sold           700 non-null    object
#  5   manufacturing_price  700 non-null    float64
#  6   sale_price           700 non-null    float64
#  7   gross_sales          700 non-null    float64
#  8   discounts            700 non-null    float64
#  9   sales                700 non-null    float64
#  10  cogs                 700 non-null    float64
#  11  profit               700 non-null    float64
#  12  tanggal              700 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), object(5)
# memory usage: 71.2+ KB

# %% [markdown]
# ## 2.c Cek dan handling missing value

# %% [markdown]
# - Cek nilai kosong

# %%
df.isnull().sum()
# Out:
# segment                0
# country                0
# product                0
# discount_band          0
# units_sold             0
# manufacturing_price    0
# sale_price             0
# gross_sales            0
# discounts              0
# sales                  0
# cogs                   0
# profit                 0
# tanggal                0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# dari keterangan di atas tidak ada nilai kosong

# %% [markdown]
# - cek data duplikat

# %%
data_duplikat = df.duplicated().sum()
print(f'data duplikat adalah: {data_duplikat}')
# Out:
# data duplikat adalah: 0

# %%
data_duplikat2 = df[df.duplicated()]
print(f'data duplikat adalah: {data_duplikat}')
# Out:
# data duplikat adalah: 0

# %%
# check stat 
df.describe()
# Out:
#        manufacturing_price  sale_price   gross_sales      discounts  \
# count           700.000000  700.000000  7.000000e+02     700.000000
# mean             96.477143  118.428571  1.827594e+05   13150.354671
# min               3.000000    7.000000  1.799000e+03       0.000000
# 25%               5.000000   12.000000  1.739175e+04     800.320000
# 50%              10.000000   20.000000  3.798000e+04    2585.250000
# 75%             250.000000  300.000000  2.790250e+05   15956.347500
# max             260.000000  350.000000  1.207500e+06  149677.500000
# std             108.602612  136.775515  2.542623e+05   22962.928760
#
#               sales           cogs         profit              tanggal
# count  7.000000e+02     700.000000     700.000000                  700
# mean   1.696091e+05  145475.211429   26354.778271  2014-04-28 21:36:00
# min    1.655080e+03     918.000000       0.000000  2013-09-01 00:00:00
# 25%    1.592800e+04    7490.000000    3815.707500  2013-12-24 06:00:00
# ...

# %% [markdown]
# ---
#
# # 3. Data Normalization

# %% [markdown]
# ## 3.a Lakukan normalisasi data yang sudah diolah sebelumnya sampai dengan 3NF

# %%
df.head()
# Out:
#       segment  country      product discount_band units_sold  \
# 0  Government   Canada   Carretera          None     1618.50
# 1  Government  Germany   Carretera          None     1321.00
# 2   Midmarket   France   Carretera          None     2178.00
# 3   Midmarket  Germany   Carretera          None      888.00
# 4   Midmarket   Mexico   Carretera          None     2470.00
#
#    manufacturing_price  sale_price  gross_sales  discounts    sales     cogs  \
# 0                  3.0        20.0      32370.0        0.0  32370.0  16185.0
# 1                  3.0        20.0      26420.0        0.0  26420.0  13210.0
# 2                  3.0        15.0      32670.0        0.0  32670.0  21780.0
# 3                  3.0        15.0      13320.0        0.0  13320.0   8880.0
# 4                  3.0        15.0      37050.0        0.0  37050.0  24700.0
#
#     profit    tanggal
# 0  16185.0 2014-01-01
# 1  13210.0 2014-01-01
# 2  10890.0 2014-06-01
# 3   4440.0 2014-06-01
# ...

# %% [markdown]
# - Normalisasi 1NF

# %%
normal_1 = df.value_counts().to_frame()
normal_1
# Out:
#                                                                                                                                                                             count
# segment          country                  product    discount_band units_sold manufacturing_price sale_price gross_sales discounts sales     cogs     profit    tanggal
# Channel Partners Canada                    Amarilla   High         2761.00    260.0               12.0       33132.0     3975.84   29156.16  8283.0   20873.16  2013-09-01      1
# Government       United States of America  Paseo      Low          274.00     10.0                350.0      95900.0     3836.00   92064.00  71240.0  20824.00  2014-12-01      1
#                                                       High         1177.00    10.0                350.0      411950.0    57673.00  354277.00 306020.0 48257.00  2014-11-01      1
# ...

# %%
normal_1[normal_1.columns].nunique()
# Out:
# count    1
# dtype: int64

# %%
# hapus kolom attribut turunan
df.drop(['gross_sales','discounts','sales','cogs'],axis=1, inplace=True)

# %%
df.head()
# Out:
#       segment  country      product discount_band units_sold  \
# 0  Government   Canada   Carretera          None     1618.50
# 1  Government  Germany   Carretera          None     1321.00
# 2   Midmarket   France   Carretera          None     2178.00
# 3   Midmarket  Germany   Carretera          None      888.00
# 4   Midmarket   Mexico   Carretera          None     2470.00
#
#    manufacturing_price  sale_price   profit    tanggal
# 0                  3.0        20.0  16185.0 2014-01-01
# 1                  3.0        20.0  13210.0 2014-01-01
# 2                  3.0        15.0  10890.0 2014-06-01
# 3                  3.0        15.0   4440.0 2014-06-01
# 4                  3.0        15.0  12350.0 2014-06-01

# %% [markdown]
# - Normalisasi 2NF

# %%
# check produt berdasarkan segment country, discount_band, manufakturing_price,dan date
normal_2 = df.groupby(['segment','country','discount_band','manufacturing_price','product','tanggal','units_sold'])['profit'].count().to_frame()
normal_2
# Out:
#                                                                                                                profit
# segment          country                  discount_band manufacturing_price product     tanggal    units_sold
# Channel Partners Canada                    High         3.0                  Carretera  2014-02-01 1937.00          1
#                                                         10.0                 Paseo      2013-11-01 2222.00          1
#                                                                                         2014-07-01 4026.00          1
#                                                         250.0                VTT        2014-05-01 2109.00          1
#                                                         260.0                Amarilla   2013-09-01 2761.00          1
# ...                                                                                                               ...
# ...

# %%
normal_2[normal_2.columns].nunique()
# Out:
# profit    1
# dtype: int64

# %% [markdown]
# ### Buat table segment

# %%
# segment
segID = [f'S{11+i}' for i in range(len(df[df.columns[0]].drop_duplicates()))] # seg_id
segmentTable= pd.DataFrame(data = {
    'seg_id':segID,
    'segment':(df[df.columns[0]].drop_duplicates()).copy()
    }
)
segmentTable
# Out:
#    seg_id           segment
# 0     S11        Government
# 2     S12         Midmarket
# 7     S13  Channel Partners
# 11    S14        Enterprise
# 12    S15    Small Business

# %% [markdown]
# ### Buat table country

# %%
# Country
c_id = [f'C{101+i}' for i in range(len(df[df.columns[1]].drop_duplicates()))] # c_id
countryTable = pd.DataFrame(data = {
    'country_id':c_id,
    'country':(df[df.columns[1]].drop_duplicates()).copy()
    }
)
countryTable
# Out:
#    country_id                   country
# 0        C101                    Canada
# 1        C102                   Germany
# 2        C103                    France
# 4        C104                    Mexico
# 15       C105  United States of America

# %% [markdown]
# ### Buat table discount_band

# %%
# discount_band
disb_id = [f'D{41+i} 'for i in range(len(df[df.columns[3]].drop_duplicates()))] # disb_id
discount_bandTable = pd.DataFrame(data = {
    'disb_id':disb_id,
    'discount_band':(df[df.columns[3]].drop_duplicates()).copy()
    }
)
discount_bandTable
# Out:
#     disb_id discount_band
# 0      D41          None
# 53     D42           Low
# 213    D43        Medium
# 455    D44          High

# %% [markdown]
# ### Buat table Product

# %%
# product dan manufacturing price
pro_id = [f'P{11+i}' for i in range(len(df[['product', 'manufacturing_price']].drop_duplicates()))] # pro_id
productTable = pd.DataFrame(data = {
    'pro_id':pro_id,
    'product':(df['product'].drop_duplicates()).copy(),
    'manufacturing_price':(df['manufacturing_price'].drop_duplicates()).copy()
    }
)
productTable
# Out:
#    pro_id      product  manufacturing_price
# 0     P11   Carretera                   3.0
# 6     P12     Montana                   5.0
# 16    P13       Paseo                  10.0
# 31    P14        Velo                 120.0
# 38    P15         VTT                 250.0
# 45    P16    Amarilla                 260.0

# %% [markdown]
# - Normalisasi 3NF

# %%
# membuat table transection
table_transection = df[['sale_price','units_sold','profit','tanggal']]
# buat index referensi
series = [i for i in range(len(table_transection))] 
# tambah id transection
table_transection.insert(loc=0, column='trans_id', value=series)


# tabel bisa di pakai jika ada order
table_transection
# Out:
#      trans_id  sale_price units_sold    profit    tanggal
# 0           0        20.0    1618.50  16185.00 2014-01-01
# 1           1        20.0    1321.00  13210.00 2014-01-01
# 2           2        15.0    2178.00  10890.00 2014-06-01
# 3           3        15.0     888.00   4440.00 2014-06-01
# 4           4        15.0    2470.00  12350.00 2014-06-01
# ..        ...         ...        ...       ...        ...
# 695       695       300.0    2475.00  12375.00 2014-03-01
# 696       696       300.0     546.00   2730.00 2014-10-01
# 697       697         7.0    1368.00   1299.60 2014-02-01
# 698       698         7.0     723.00    686.85 2014-04-01
# 699       699        12.0    1806.00  13003.20 2014-05-01
#
# [700 rows x 5 columns]

# %% [markdown]
# # Buat main table

# %%
# buat mainTable
mainTable = df[df.columns[0:4]]

# index masing - masing table
segID=[]
c_id=[]
disb_id=[]
pro_id=[]

# masukan index id ke dalam list dengan cara mengecek setiap value
for i in range(len(mainTable)):
    for j in range(len(segmentTable)):
        if mainTable.iloc[i,0] == segmentTable.iloc[j,1]:
            segID.append(segmentTable.iloc[j,0])
            break
    for j in range(len(countryTable)):
        if mainTable.iloc[i,1] == countryTable.iloc[j,1]:
            c_id.append(countryTable.iloc[j,0])
            break

    for j in range(len(productTable)):
        if mainTable.iloc[i,2] == productTable.iloc[j,1]:  
            pro_id.append(productTable.iloc[j,0])        
            break

    for j in range(len(discount_bandTable)):
        if mainTable.iloc[i,3] == discount_bandTable.iloc[j,1]:  
            disb_id.append(discount_bandTable.iloc[j,0])          
            break

# Mengganti nama kolom menjadi 'trans_id'
mainTable = mainTable.copy()

# Menyisipkan kolom-kolom baru
mainTable.insert(0, column='seg_id', value=segID)
mainTable.insert(1, column='country_id', value=c_id)
mainTable.insert(2, column='pro_id', value=pro_id)
mainTable.insert(3, column='disb_id', value=disb_id) 

mainTable
# Out:
#     seg_id country_id pro_id disb_id           segment  \
# 0      S11       C101    P11    D41         Government
# 1      S11       C102    P11    D41         Government
# 2      S12       C103    P11    D41          Midmarket
# 3      S12       C102    P11    D41          Midmarket
# 4      S12       C104    P11    D41          Midmarket
# ..     ...        ...    ...     ...               ...
# 695    S15       C103    P16    D44     Small Business
# 696    S15       C104    P16    D44     Small Business
# 697    S11       C104    P12    D44         Government
# 698    S11       C101    P13    D44         Government
# 699    S13       C105    P15    D44   Channel Partners
#
#                       country      product discount_band
# 0                      Canada   Carretera          None
# 1                     Germany   Carretera          None
# 2                      France   Carretera          None
# 3                     Germany   Carretera          None
# ...

# %%
# test tabel relasi
test = pd.concat([mainTable,table_transection], axis=1)
test
# Out:
#     seg_id country_id pro_id disb_id           segment  \
# 0      S11       C101    P11    D41         Government
# 1      S11       C102    P11    D41         Government
# 2      S12       C103    P11    D41          Midmarket
# 3      S12       C102    P11    D41          Midmarket
# 4      S12       C104    P11    D41          Midmarket
# ..     ...        ...    ...     ...               ...
# 695    S15       C103    P16    D44     Small Business
# 696    S15       C104    P16    D44     Small Business
# 697    S11       C104    P12    D44         Government
# 698    S11       C101    P13    D44         Government
# 699    S13       C105    P15    D44   Channel Partners
#
#                       country      product discount_band  trans_id  \
# 0                      Canada   Carretera          None          0
# 1                     Germany   Carretera          None          1
# 2                      France   Carretera          None          2
# ...

# %%
table_main = test.copy()
# karena sudah ada inisialisasi jadi drop
table_main.drop(['segment','country','product','discount_band'],axis=1, inplace=True)

# %%
table_main
# Out:
#     seg_id country_id pro_id disb_id  trans_id  sale_price units_sold  \
# 0      S11       C101    P11    D41          0        20.0    1618.50
# 1      S11       C102    P11    D41          1        20.0    1321.00
# 2      S12       C103    P11    D41          2        15.0    2178.00
# 3      S12       C102    P11    D41          3        15.0     888.00
# 4      S12       C104    P11    D41          4        15.0    2470.00
# ..     ...        ...    ...     ...       ...         ...        ...
# 695    S15       C103    P16    D44        695       300.0    2475.00
# 696    S15       C104    P16    D44        696       300.0     546.00
# 697    S11       C104    P12    D44        697         7.0    1368.00
# 698    S11       C101    P13    D44        698         7.0     723.00
# 699    S13       C105    P15    D44        699        12.0    1806.00
#
#        profit    tanggal
# 0    16185.00 2014-01-01
# 1    13210.00 2014-01-01
# 2    10890.00 2014-06-01
# ...

# %% [markdown]
# ## 3.b Jumlah tabel setelah dinormalisasi sebanyak 5 tabel termasuk tabel utama.

# %% [markdown]
# - Table Segment

# %%
segmentTable
# Out:
#    seg_id           segment
# 0     S11        Government
# 2     S12         Midmarket
# 7     S13  Channel Partners
# 11    S14        Enterprise
# 12    S15    Small Business

# %% [markdown]
# Untuk tabel segment id primary nya adalah  seg_id

# %% [markdown]
# - Table Country

# %%
countryTable
# Out:
#    country_id                   country
# 0        C101                    Canada
# 1        C102                   Germany
# 2        C103                    France
# 4        C104                    Mexico
# 15       C105  United States of America

# %% [markdown]
# Untuk tabel country primary key nya adalah country_id

# %% [markdown]
# - Table Product

# %%
productTable
# Out:
#    pro_id      product  manufacturing_price
# 0     P11   Carretera                   3.0
# 6     P12     Montana                   5.0
# 16    P13       Paseo                  10.0
# 31    P14        Velo                 120.0
# 38    P15         VTT                 250.0
# 45    P16    Amarilla                 260.0

# %% [markdown]
# Untuk tabel product primary key nya adalah pro_id

# %% [markdown]
# - Table Discount Band

# %%
discount_bandTable
# Out:
#     disb_id discount_band
# 0      D41          None
# 53     D42           Low
# 213    D43        Medium
# 455    D44          High

# %% [markdown]
# Untuk tabel discount_band primary key nya adalah disb_id

# %% [markdown]
# - Table Main

# %%
table_main
# Out:
#     seg_id country_id pro_id disb_id  trans_id  sale_price units_sold  \
# 0      S11       C101    P11    D41          0        20.0    1618.50
# 1      S11       C102    P11    D41          1        20.0    1321.00
# 2      S12       C103    P11    D41          2        15.0    2178.00
# 3      S12       C102    P11    D41          3        15.0     888.00
# 4      S12       C104    P11    D41          4        15.0    2470.00
# ..     ...        ...    ...     ...       ...         ...        ...
# 695    S15       C103    P16    D44        695       300.0    2475.00
# 696    S15       C104    P16    D44        696       300.0     546.00
# 697    S11       C104    P12    D44        697         7.0    1368.00
# 698    S11       C101    P13    D44        698         7.0     723.00
# 699    S13       C105    P15    D44        699        12.0    1806.00
#
#        profit    tanggal
# 0    16185.00 2014-01-01
# 1    13210.00 2014-01-01
# 2    10890.00 2014-06-01
# ...

# %% [markdown]
# Tabel main memiliki foreign key seg_id, country_id, pro_id,disb_id dan untuk primary key adalah trans id

# %% [markdown]
# ## 3. export to csv

# %%
# export segement to csv
segmentTable.to_csv('segment.csv', index=False)

# %%
# export table_country to csv
countryTable.to_csv('country.csv', index=False)

# %%
# export table_discount_band to csv
discount_bandTable.to_csv('discount_band.csv', index=False)

# %%
# export table_product to csv
productTable.to_csv('product.csv', index=False)

# %%
# export table_relasi to csv
table_main.to_csv('main.csv', index=False)

# %%
df
# Out:
#               segment                   country      product discount_band  \
# 0          Government                    Canada   Carretera          None
# 1          Government                   Germany   Carretera          None
# 2           Midmarket                    France   Carretera          None
# 3           Midmarket                   Germany   Carretera          None
# 4           Midmarket                    Mexico   Carretera          None
# ..                ...                       ...          ...           ...
# 695    Small Business                    France    Amarilla          High
# 696    Small Business                    Mexico    Amarilla          High
# 697        Government                    Mexico     Montana          High
# 698        Government                    Canada       Paseo          High
# 699  Channel Partners  United States of America         VTT          High
#
#     units_sold  manufacturing_price  sale_price    profit    tanggal
# ...

# %% [markdown]
# ---
# # Pengujian database

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 data_total_profit = pd.read_csv('C:\temp\total_profit')
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...
